# %% [markdown]
# # Onelab — AI Fitness Assessment
#
# ## Problem
# Reconcile platform transactions with bank settlements and identify mismatches.
#
# ## Goal
# Detect gaps such as:
# - Timing differences
# - Rounding errors
# - Duplicates
# - Missing / orphan records

# %% [markdown]
# ## Assumptions
#
# 1. Each transaction has a unique ID (except duplicates we inject)
# 2. Settlements occur 1–2 days after transaction
# 3. Matching is primarily based on transaction ID
# 4. Refunds are represented as negative amounts
# 5. Single currency (no FX complications)

# %%
import pandas as pd

def generate_data():
    transactions = pd.DataFrame({
        "id": ["t1", "t2", "t3", "t4", "t5", "t5"],  # duplicate
        "amount": [100.00, 200.00, 300.00, 150.25, 99.99, 99.99],
        "timestamp": pd.to_datetime([
            "2024-01-28",
            "2024-01-29",
            "2024-01-30",
            "2024-01-31",
            "2024-01-31",
            "2024-01-31"
        ])
    })

    settlements = pd.DataFrame({
        "id": ["t1", "t2", "t3", "t4", "t6"],
        "amount": [100.00, 200.00, 300.00, 150.24, -50.00],
        "settlement_date": pd.to_datetime([
            "2024-01-29",
            "2024-01-30",
            "2024-02-01",  # next month case
            "2024-02-01",
            "2024-01-31"
        ])
    })

    return transactions, settlements

transactions, settlements = generate_data()

transactions, settlements
# Out:
# (   id  amount  timestamp
#  0  t1  100.00 2024-01-28
#  1  t2  200.00 2024-01-29
#  2  t3  300.00 2024-01-30
#  3  t4  150.25 2024-01-31
#  4  t5   99.99 2024-01-31
#  5  t5   99.99 2024-01-31,
#     id  amount settlement_date
#  0  t1  100.00      2024-01-29
#  1  t2  200.00      2024-01-30
#  2  t3  300.00      2024-02-01
#  3  t4  150.24      2024-02-01
#  4  t6  -50.00      2024-01-31)

# %%
def reconcile(transactions, settlements):

    # Detect duplicates
    duplicates = transactions[transactions.duplicated(subset=["id"], keep=False)]

    # Merge
    merged = pd.merge(
        transactions,
        settlements,
        on="id",
        how="outer",
        suffixes=("_txn", "_set")
    )

    # Unmatched
    unmatched_txns = merged[merged["amount_set"].isna()]
    unmatched_settlements = merged[merged["amount_txn"].isna()]

    # Rounding differences
    merged["diff"] = merged["amount_txn"] - merged["amount_set"]
    rounding_issues = merged[merged["diff"].abs() > 0.01]

    # Totals
    total_txn = transactions["amount"].sum()
    total_set = settlements["amount"].sum()

    return {
        "duplicates": duplicates,
        "unmatched_txns": unmatched_txns,
        "unmatched_settlements": unmatched_settlements,
        "rounding_issues": rounding_issues,
        "total_txn": total_txn,
        "total_set": total_set,
        "difference": total_txn - total_set
    }

result = reconcile(transactions, settlements)

# %%
print("=== SUMMARY ===")
print("Total Transactions:", result["total_txn"])
print("Total Settlements:", result["total_set"])
print("Difference:", result["difference"])

print("\n=== DUPLICATES ===")
display(result["duplicates"])

print("\n=== UNMATCHED TRANSACTIONS ===")
display(result["unmatched_txns"])

print("\n=== UNMATCHED SETTLEMENTS ===")
display(result["unmatched_settlements"])

print("\n=== ROUNDING ISSUES ===")
display(result["rounding_issues"])
# Out:
# === SUMMARY ===
# Total Transactions: 950.23
# Total Settlements: 700.24
# Difference: 249.99
#
# === DUPLICATES ===
#    id  amount  timestamp
# 4  t5   99.99 2024-01-31
# 5  t5   99.99 2024-01-31
# === UNMATCHED TRANSACTIONS ===
#    id  amount_txn  timestamp  amount_set settlement_date
# 4  t5       99.99 2024-01-31         NaN             NaT
# 5  t5       99.99 2024-01-31         NaN             NaT
# === UNMATCHED SETTLEMENTS ===
#    id  amount_txn timestamp  amount_set settlement_date
# 6  t6         NaN       NaT       -50.0      2024-01-31
# === ROUNDING ISSUES ===
# Empty DataFrame
# Columns: [id, amount_txn, timestamp, amount_set, settlement_date, diff]
# Index: []

# %%
# Duplicate test
assert not result["duplicates"].empty

# Next month settlement test
assert any(settlements["settlement_date"].dt.month == 2)

# Rounding issue test
assert abs(result["difference"]) > 0

# Orphan refund test
assert any(result["unmatched_settlements"]["amount_set"] < 0)

print("All tests passed ✅")
# Out:
# All tests passed ✅

# %%
import matplotlib.pyplot as plt

# %%
summary = {
    "Total Transactions": result["total_txn"],
    "Total Settlements": result["total_set"],
    "Difference": result["difference"],
    "Duplicates": len(result["duplicates"]),
    "Unmatched Transactions": len(result["unmatched_txns"]),
    "Unmatched Settlements": len(result["unmatched_settlements"]),
    "Rounding Issues": len(result["rounding_issues"])
}

summary
# Out:
# {'Total Transactions': np.float64(950.23),
#  'Total Settlements': np.float64(700.24),
#  'Difference': np.float64(249.99),
#  'Duplicates': 2,
#  'Unmatched Transactions': 2,
#  'Unmatched Settlements': 1,
#  'Rounding Issues': 0}

# %%
labels = [
    "Duplicates",
    "Unmatched Txns",
    "Unmatched Settlements",
    "Rounding Issues"
]

values = [
    summary["Duplicates"],
    summary["Unmatched Transactions"],
    summary["Unmatched Settlements"],
    summary["Rounding Issues"]
]

plt.figure()
plt.bar(labels, values)
plt.title("Reconciliation Issues Breakdown")
plt.xlabel("Issue Type")
plt.ylabel("Count")
plt.xticks(rotation=20)

plt.show()

# %%
plt.figure()
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.title("Issue Distribution")

plt.show()

# %%
print("💰 Financial Discrepancy:", summary["Difference"])
# Out:
# 💰 Financial Discrepancy: 249.99

# %%
import pandas as pd

dashboard_df = pd.DataFrame([summary])
dashboard_df
# Out:
#    Total Transactions  Total Settlements  Difference  Duplicates  \
# 0              950.23             700.24      249.99           2
#
#    Unmatched Transactions  Unmatched Settlements  Rounding Issues
# 0                       2                      1                0
